# %% [markdown]
# <div class="alert alert-success"><div class='alert btn-success'>
# Максим, оставила еще пару полезных комментарием, надеюсь, пригодятся ))<br>
# Критичных ошибок нет. Молодец!)<br>
# Здорово, что обращаешь внимание на советы и применяешь на практике, значит не зря я их раздаю:) <br>
# С удовольствием принимаю проект!<br>
#
# </div></div>
#
# Очень рекомендую посмотреть видео от Глеба Михайлова!)<br>
# **[Линейная Регрессия для Дата Саентиста](https://www.youtube.com/watch?v=QZJ94igWVxQ&t=19s)**     <br>
#
# **[Вот здесь есть отличное объяснение с примером по мультиколлинеарности.](https://habr.com/ru/company/akbarsdigital/blog/592493/)** <br>
#
# **[И здесь интересная статься - коротко о мультиколлинеарности и что с этим делать.](https://medium.com/analytics-vidhya/removing-multi-collinearity-for-linear-and-logistic-regression-f1fa744f3666)** <br>
#
# **[Если интересна статистика, можно посмотреть короткие видео-лекции Карпова на степике](https://stepik.org/lesson/8095/step/1?unit=1371)**    <br>
#
#
# <br>
# <div class="alert alert-success"><div class='alert btn-success'>
# Надеюсь, ты найдешь для себя что-то интересное и полезное😊  <br>
# Желаю тебе удачи в дальнейшей учебе! 😉 </div></div>

# %% [markdown]
# Максим, привет! Меня зовут Ирина Литвинова. Сегодня я проверю твой проект.<br>
# <br> Ты можешь обращаться ко мне на "ты"😏 Надеюсь, ты не будешь против, если и я буду обращаться к тебе на "ты". Но если для тебя это неприемлeмо, дай знать, пожалуйста) <br>
# <br> Мне очень важна твоя реакция на мои комментарии, особенно <font color='red'>красные</font>. Можешь реагировать, например, так ('исправлено', ...)<br>
# <br> Ты можешь реагировать на мои комментарии своими, выделяя их цветами и наиболее понравившимся тебе способом оформления, но явно  отличающимся от моих комментариев. <br>
# Это нужно, чтобы не создавалась путаница😉<br>
# Например, так:<br>
#
# <div class="alert alert-block alert-info"><b>Комментарий студента</b>
#
# <b>Изменения:</b> Были внесены следующие изменения ...<br></div>
#
#
# <br> Пожалуйста, не удаляй мои комментарии, так как они повышают качество повторного ревью и делают его быстрее)<br>
# <br> Увидев у тебя неточность, в первый раз я лишь укажу на ее наличие и дам тебе возможность самостоятельно найти и исправить ее. На реальной работе твой руководитель будет поступать также, и я пытаюсь подготовить тебя именно к работе. Но если ты пока не справишься с такой задачей - при следующей проверке я дам более точную подсказку!🤓<br>
#
# Для твоего удобства мои комментарии будут в <font color='green'>зеленой</font>, <font color='orange'>желтой</font> или <font color='red'>красной</font> рамках:<br>
# <br>
#
# <div class="alert alert-block alert-danger"><b>Комментарий ревьюера</b>
#
# <b>Ошибка:</b><br>
# Если требуются исправления. Работа не может быть принята с красными комментариями.<br></div>
#
# <div class="alert alert-block alert-warning"><b>Комментарий ревьюера</b>
#
# <b>Совет:</b><br>
# Если можно немного улучшить.<br></div>
#
# <div class="alert alert-block alert-success"><b>Комментарий ревьюера</b>
#
# <b>Успех:</b><br>
# Если все сделано отлично.<br></div>

# %% [markdown]
# # Выбор локации для скважины

# %% [markdown]
# Допустим, вы работаете в добывающей компании «ГлавРосГосНефть». Нужно решить, где бурить новую скважину.
#
# Вам предоставлены пробы нефти в трёх регионах: в каждом 10 000 месторождений, где измерили качество нефти и объём её запасов. Постройте модель машинного обучения, которая поможет определить регион, где добыча принесёт наибольшую прибыль. Проанализируйте возможную прибыль и риски техникой *Bootstrap.*
#
# Шаги для выбора локации:
#
# - В избранном регионе ищут месторождения, для каждого определяют значения признаков;
# - Строят модель и оценивают объём запасов;
# - Выбирают месторождения с самым высокими оценками значений. Количество месторождений зависит от бюджета компании и стоимости разработки одной скважины;
# - Прибыль равна суммарной прибыли отобранных месторождений.

# %% [markdown]
# <div class="alert alert-block alert-success"><b>Комментарий ревьюера</b>
#
# <b>Успех:</b><br>
# 👍 Есть введение в проект. Отлично!<br>
#
# </div>

# %% [markdown]
# ## Загрузка и подготовка данных

# %% [markdown]
# Объявим все нужные библиотеки для данного проекта:

# %% [markdown]
# ![2023-02-07_10-06-40.png](attachment:2023-02-07_10-06-40.png)

# %% [markdown]
# <div class="alert alert-block alert-warning"><b>Комментарий ревьюера V-2</b>
#
# <b>Совет:</b><br>
# Максим, у тебя ячейки начинались не с первой. Я проверила - код работает. Но лучше перед отправкой проекта проверять работоспособность кода - это можно сделать, нажав на панели Jupiter Hub 👉 **Kernel** 👉  **Restart & Run All** .<br>
# Потом обязательно сохрани. Для этого сделай так: 👉  **File**  👉   **Save and Checkpoint** .
# Когда сохранишь, пожалуйста, проверь - обрати внимание на сообщение "**Последняя контрольная точка: несколько секунд назад
# (автосохранение)**" <br>
# </div>

# %% [markdown]
# ![2022-06-25_09-17-28.png](attachment:2022-06-25_09-17-28.png)

# %% [markdown]
# ![2022-06-26_15-59-11.png](attachment:2022-06-26_15-59-11.png)

# %%
import pandas as pd
import numpy as np
from numpy import arange

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import StandardScaler 
from sklearn.utils import shuffle
from sklearn.compose import make_column_transformer
from sklearn.metrics import mean_squared_error

pd.options.mode.chained_assignment = None

# %% [markdown]
# Объявим известную информацию о разработке скважин и добавим эти константы.

# %% [markdown]
# <div class="alert alert-block alert-success"><b>Комментарий ревьюера </b>
#
# <b>Успех:</b><br>
# 👍 Здорово, что импортируешь необходимые библиотеки в первой ячейке. Так сразу понятно какие используются библиотеки и можно легко настроить свое окружение при необходимости.
# * Обрати внимание, есть повторы)
# </div>

# %%
BUDGET = 10e9
NUMBER_WELLS = 200
PROFIT_BARREL = 45e4

# %% [markdown]
# <div class="alert alert-block alert-success"><b>Комментарий ревьюера V-2</b><br>
#
# Приятно, что прислушиваешься к советам))
# </div>

# %% [markdown]
# Датафреймы считаны и проведена оценка полученных данных.

# %%
df1 = pd.read_csv('/datasets/geo_data_0.csv')
df1.info()
display(df1.describe())

df2 = pd.read_csv('/datasets/geo_data_1.csv')
df2.info()
display(df2.describe())

df3 = pd.read_csv('/datasets/geo_data_2.csv')
df3.info()
df3.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 5 columns):
#  #   Column   Non-Null Count   Dtype
# ---  ------   --------------   -----
#  0   id       100000 non-null  object
#  1   f0       100000 non-null  float64
#  2   f1       100000 non-null  float64
#  3   f2       100000 non-null  float64
#  4   product  100000 non-null  float64
# dtypes: float64(4), object(1)
# memory usage: 3.8+ MB
#                   f0             f1             f2        product
# count  100000.000000  100000.000000  100000.000000  100000.000000
# mean        0.500419       0.250143       2.502647      92.500000
# std         0.871832       0.504433       3.248248      44.288691
# min        -1.408605      -0.848218     -12.088328       0.000000
# 25%        -0.072580      -0.200881       0.287748      56.497507
# 50%         0.502360       0.250252       2.515969      91.849972
# 75%         1.073581       0.700646       4.715088     128.564089
# ...

# %% [markdown]
# В данных `нет пропусков`, столбцы `f0 f1 f2` требуют маштабирования для дальнейшего обучения.
#
# Также присутсвует неинформативный столбец `id`

# %%
df1 = df1.drop_duplicates(subset = 'id', keep = False)
display(df1)

df2 = df2.drop_duplicates(subset = 'id', keep = False)
display(df2)

df3 = df3.drop_duplicates(subset = 'id', keep = False)
display(df3)
# Out:
#           id        f0        f1        f2     product
# 0      txEyH  0.705745 -0.497823  1.221170  105.280062
# 1      2acmU  1.334711 -0.340164  4.365080   73.037750
# 2      409Wp  1.022732  0.151990  1.419926   85.265647
# 3      iJLyR -0.032172  0.139033  2.978566  168.620776
# 4      Xdl7t  1.988431  0.155413  4.751769  154.036647
# ...      ...       ...       ...       ...         ...
# 99995  DLsed  0.971957  0.370953  6.075346  110.744026
# 99996  QKivN  1.392429 -0.382606  1.273912  122.346843
# 99997  3rnvd  1.029585  0.018787 -1.348308   64.375443
# 99998  7kl59  0.998163 -0.528582  1.583869   74.040764
# 99999  1CWhH  1.764754 -0.266417  5.722849  149.633246
#
# [99980 rows x 5 columns]
#           id         f0         f1        f2     product
# 0      kBEdx -15.001348  -8.276000 -0.005876    3.179103
# 1      62mP7  14.272088  -3.475083  0.999183   26.953261
# 2      vyE1P   6.263187  -5.948386  5.001160  134.766305
# ...

# %% [markdown]
# Были устранены дубликаты скважин, удалению подверглись все дубликаты, так как неизвестно исходя из чего они могли появиться, можно ли их сложить или же это исправление раннее ошибочных данных. Для обучения такие строки увеличивали вероятность ошибки предсказания.

# %% [markdown]
# <div class="alert alert-block alert-success"><b>Комментарий ревьюера </b>
#
# <b>Успех:</b><br>
# 👍 Хорошо, что обращаешь внимание на дубликаты по `id`. Так как нам не ясна природа таких дубликатов, то их можно как удалить, так и оставить. Но о таких фактах всегда надо сообщать коллегам.
# </div>

# %% [markdown]
# <div class="alert alert-block alert-warning"><b>Комментарий ревьюера</b>
#
# <b>Совет:</b><br>
# Максим,
# * Чтобы лучше узнать данные, можно посмотреть распределение признаков и целевой переменной для каждого региона, т.е. построить гистограмму.
# * Еще важно уделять внимание мультиколлинеарности признаков в линейных моделях.<br>
# Мультиколлинеарность — явление, при котором наблюдается сильная корреляция между признаками, что может негативно отразиться на модели.<br>
#
# Рекомендую посмотреть отрывок из курса Статистики - ["Корреляция и регрессия".](https://stepik.org/lesson/8086/step/1?unit=1365) <br>
# Для удобной визуализации можно использовать - ["Тепловая карта корреляции".](https://www.delftstack.com/ru/howto/seaborn/correlation-heatplot-seaborn-python/) <br>
# </div>

# %%
# !pip install scikit-learn==1.1.3
target_1 = df1['product']
target_2 = df2['product']
target_3 = df3['product']
features_1 = df1.drop(['id','product'], axis = 1)
features_2 = df2.drop(['id','product'], axis = 1)
features_3 = df3.drop(['id','product'], axis = 1)
# Out:
# ...
#      |████████████████████████████████| 30.8 MB 1.9 MB/s eta 0:00:01
# ...
#   Attempting uninstall: scikit-learn
#     Found existing installation: scikit-learn 0.24.1
#     Uninstalling scikit-learn-0.24.1:
#       Successfully uninstalled scikit-learn-0.24.1
# ...

# %% [markdown]
# <div class="alert alert-block alert-success"><b>Комментарий ревьюера </b>
#
# <b>Успех:</b><br>
# 👍 `id`  - уникальный идентификатор скважины, он не является признаком, поэтому его действительно лучше удалить.
# </div>

# %% [markdown]
# Данные разбиты на целевые и обучающие признаки.

# %%
features1_train, features1_valid, target1_train, target1_valid \
        = train_test_split(features_1, target_1,\
        test_size=0.25, random_state=12345)# делим тестовые выборки со свапом

# %%
features2_train, features2_valid, target2_train, target2_valid \
        = train_test_split(features_2, target_2, \
        test_size=0.25, random_state=12345)# делим тестовые выборки со свапом

# %%
features3_train, features3_valid, target3_train, target3_valid \
        = train_test_split(features_3, target_3, \
        test_size=0.25, random_state=12345)# делим тестовые выборки со свапом

target2_train = target2_train.reset_index(drop=True)
target2_valid = target2_valid.reset_index(drop =True)
target1_train = target1_train.reset_index(drop =True)
target1_valid = target1_valid.reset_index(drop =True)
target3_valid = target3_valid.reset_index(drop =True)
target3_train = target3_train.reset_index(drop =True)

# %% [markdown]
# Данные разбиты на обучающие и валидационные выборки в соотношении 25:75.
#
# Также были сброшены индексы для feature и target, для простоты дальнейшей работы.

# %% [markdown]
# <div class="alert alert-block alert-success"><b>Комментарий ревьюера </b>
#
# <b>Успех:</b><br>
# 👍
# * Данные разделены на обучающую и валидационную выборку корректно - 75:25. Будет надежнее, если после разбиения проверять доли)
#
# * Хорошо, что не забываешь про индексы, теперь у таргета и предсказаний они будут совпадать
#
#
# </div>

# %%
def scaler_main(features_train,features_valid):
    scaler = StandardScaler()
    scaler.fit(features_train)

    features_train = pd.DataFrame(scaler.transform(features_train),\
                                   columns = features_valid.columns).reset_index(drop = True)
    features_valid = pd.DataFrame(scaler.transform(features_valid),\
                                   columns = features_train.columns).reset_index(drop = True)
    return features_train,features_valid

# %%
features1_train, features1_valid = scaler_main(features1_train,features1_valid)
features2_train, features2_valid = scaler_main(features2_train,features2_valid)
features3_train, features3_valid = scaler_main(features3_train,features3_valid)

# %% [markdown]
# Функция маштабирования обучена на обучающей выборке и применена для преобразования f0 f1 f2, для всех трех регионов.

# %% [markdown]
# <div class="alert alert-block alert-success"><b>Комментарий ревьюера </b>
#
# <b>Успех:</b><br>
# 👍 Отлично, что используешь функцию для повторяющихся действий
#
#
# </div>

# %% [markdown]
# Данные готовы для дальнейшего обучения!

# %% [markdown]
# ## Обучение и проверка модели

# %% [markdown]
# Воспользуемся моделью линейной регрессии так как она лучше всего подходит для данной задачи и оценим качество подели по метрике R2.

# %%
def ML_linear(features_train,target_train,features_valid,target_valid,region):
    best_R2 = 0
    model = LinearRegression() 
    model.fit(features_train, target_train) 
    volume = model.predict(features_valid)
    R2 = model.score(features_valid,target_valid)
    best_R2 = R2 
    mse = mean_squared_error(target_valid, volume)
    print(f"{region} регион\nRMSE = {mse ** 0.5}")
    print(f"Среднее значение объема скважины:{volume.mean()}+-{mse ** 0.5}")
    print(f"R2 для {region} региона - {best_R2}\n")
    return model,volume,mse ** 0.5

# %%
modelLR1,volume1,mse1 = ML_linear(features1_train,target1_train,features1_valid,target1_valid,1)
modelLR2,volume2,mse2 = ML_linear(features2_train,target2_train,features2_valid,target2_valid,2)
modelLR3,volume3,mse3 = ML_linear(features3_train,target3_train,features3_valid,target3_valid,3)
# Out:
# 1 регион
# RMSE = 37.716904960382735
# Среднее значение объема скважины:92.42384109947359+-37.716904960382735
# R2 для 1 региона - 0.2766598499599884
#
# 2 регион
# RMSE = 0.891490139034854
# Среднее значение объема скважины:68.98311857983121+-0.891490139034854
# R2 для 2 региона - 0.9996239095602003
#
# 3 регион
# RMSE = 39.975543264382345
# Среднее значение объема скважины:95.11622302076478+-39.975543264382345
# R2 для 3 региона - 0.19558409993606407

# %% [markdown]
# Воспользуемся функцией для обучения модели на данных праметрах скважин.

# %% [markdown]
# После обучения модели на данных из трех регионов, можно сказать что лучше всего обучилась модель из второго региона, ее значенич `R2 - 0.99`, эта модель дает практически идеальные предсказания. Похуже обучена модель из первого региона с `R2 - 0.27`, а также третьего `R2 - 0.195`

# %% [markdown]
# <div class="alert alert-block alert-warning"><b>Комментарий ревьюера</b>
#
# <b>Совет:</b><br>
# Расчет `rmse`  и `среднего` можно добавить в функцию `ML_linear`
# </div>

# %% [markdown]
# <div class="alert alert-info">
#     <h2> Комментарий студента <a class="tocSkip"></h2>
#
# <b> Замечения учтены, RMSE and mean добавлены в функцию!</b>

# %% [markdown]
# <div class="alert alert-block alert-success"><b>Комментарий ревьюера V-2</b><br>
#
# Отлично!)
# </div>

# %% [markdown]
# По результатам предсказания модели, можно сказать что самая малая погрешность у модели, которая обучалась на данных из второго региона, ее среднее значения запасов сырья: `68+-0.89`.
#
# Но во всех остальных регионах в среднем намного больше самого сырья:
# - Для первого региона : `92+-38`
# - Для третьего региона : `95+-40`
#
# Можно подумать, что предпочтение упадет на первый и второй регион, но тот факт что для второго региона мы можем предсказать объемы практически со 100 процентной веростностью может сыграть в будущем в его пользу

# %% [markdown]
# <div class="alert alert-block alert-success"><b>Комментарий ревьюера</b>
#
# <b>Успех:</b><br>
#     👍 Молодец, что обращаешь внимание на размер ошибки, в двух других регионах она катастрофически большая - почти 40% от  среднего запаса. Если ошибка (RMSE) меньше, значит прогноз точнее и модель лучше обучилась. Если посмотреть корреляцию между признаками и целевой переменной, можно понять почему в одном из регионов ошибка минимальная. Высокий коэффициент корреляции `f2` и целевой переменной говорит о сильной прямой линейной зависимости.
# <br>
# Т.к. средний запас в каждом регионе ниже объема безубыточности и при выборе скважин опираемся на предсказания, то качество предсказания имеет огромное значение - важно определить скважины с максимальным запасом.
# </div>

# %% [markdown]
# ## Подготовка к расчёту прибыли

# %% [markdown]
# Получим минимальное значения запаса вярья для безубыточной разработки.

# %% [markdown]
# <div class="alert alert-block alert-warning"><b>Комментарий ревьюера</b>
#
# <b>Совет:</b><br>
# * Согласно руководству по написанию кода на Python [PEP-8](https://pythonworld.ru/osnovy/pep-8-rukovodstvo-po-napisaniyu-koda-na-python.html#section-29) названия констант принято задавать заглавными буквами, например, `BUDGET`. А еще важно объявлять их в начале проекта после импортов, затем загрузка данных. Так проще будет их найти и изменить, если возникнет такая необходимость.
# * Для записи больших чисел и более удобного чтения, чтобы не запутаться в нулях, можно использовать такую запись: `10_000_000_000` или `10e9`, что означает 10 * 10**9.
# </div>

# %% [markdown]
# <div class="alert alert-info">
#     <h2> Комментарий студента <a class="tocSkip"></h2>
#
# <b> Замечения учтены, константы объявлены в начале работы!</b>

# %%
product_min = (BUDGET/NUMBER_WELLS)/PROFIT_BARREL
print('Минимальные запасы сырья в скважине для безубыточности разработки:',round(product_min))
print(f"\nСреднее количество запасов в первом регионе: {target_1.mean()}\n\
Среднее количество запасов во втором регионе: {target_2.mean()}\n\
Среднее количество запасов в третьем регионе: {target_3.mean()}")
# Out:
# Минимальные запасы сырья в скважине для безубыточности разработки: 111
#
# Среднее количество запасов в первом регионе: 92.49916597893444
# Среднее количество запасов во втором регионе: 68.82414772665173
# Среднее количество запасов в третьем регионе: 94.99876686768079

# %% [markdown]
# <div class="alert alert-block alert-success"><b>Комментарий ревьюера </b>
#
# <b>Успех:</b><br>
# 👍 Достаточный объём сырья для безубыточной разработки новой скважины рассчитан верно.
# </div>

# %% [markdown]
# Можно сделать вывод, что не один регион `не подходит` для выгодной разработки скважин, так как минимальные запасы сырья `для безубыточности должны быть равны 111 тыс.бар`.
#
# Единственным вариантом заработка с минимальными рисками в данной ситуации является предсказание самых больших по объему скважин с помощью `машинного обучения`

# %% [markdown]
# <div class="alert alert-block alert-warning"><b>Комментарий ревьюера</b>
#
# <b>Совет:</b><br>
# Корректнее объём сырья для безубыточной разработки скважины сравнивать со средним реальным запасом продукта во всем регионе, а не с предсказанными значениями) Но результаты будут совпадать:)
# </div>

# %% [markdown]
# <div class="alert alert-info">
#     <h2> Комментарий студента <a class="tocSkip"></h2>
#
# <b> Замечения учтены, посчитано среднее реальных значений!</b>

# %% [markdown]
# <div class="alert alert-block alert-success"><b>Комментарий ревьюера </b><br>
#
# В каждом регионе средний объем сырья меньше достаточного объёма для безубыточности и при выборе скважин опираемся на предсказания, поэтому точность прогноза имеет большое значение и без модели нам не обойтись.  <br>
#
# Есть 25 000 точек, из которых в результате надо выбрать 200. В результате,  среди этих скважин могут быть скважины с достаточным и недостаточным запасом сырья. <br>
#
# Имеено техника "Bootstrap" опираясь на предсказания позволяет оценить риск убытков при случайным отборе 500 точек. 1000 раз отбирая случайным образом точки, считаем какой % случаев принесет убытки.
#
#
# </div>

# %% [markdown]
# ## Расчёт прибыли и рисков

# %% [markdown]
# В данном параграфе нужно написать функцию для рассчета прибыльности выбранных 200 скавжин на основе предсказания модели машинного обучения, исходя из начального набора исследуемых 500 скважин.
#
# А дальше провести анализ рисков и прибыльности на полученных данных

# %%
def profit(target,predictions):
    result = pd.concat([target,predictions], axis = 1)
    result = result.sort_values(by = ['predict']).reset_index(drop = True)
    choise = result[result.index >= 300]
    return choise['profits'].sum()*PROFIT_BARREL

# %% [markdown]
# <div class="alert alert-block alert-warning"><b>Комментарий ревьюера</b>
#
# <b>Совет:</b><br>
# В функции `profit` нет необходимости предсказывать, уже есть предсказания для валид.выборки, можно их использовать.
# * В фукцию `profit` лучше передать датасет с таргетом и предсказаниями для валид.выборки, например, для первого региона - создать датасет с `target1_valid` и `volume1` и передать в функцию прибыли.
# * Отсортировать по предсказаниям по убыванию.
# * Взять первые 200 значений таргета (они будут соответствовать лучшим предсказаниям).
# * И рассчитать прибыль.
# </div>

# %% [markdown]
# <div class="alert alert-info">
#     <h2> Комментарий студента <a class="tocSkip"></h2>
#
# <b> Замечения учтены, функция скорректирована!</b>

# %% [markdown]
# <div class="alert alert-block alert-success"><b>Комментарий ревьюера V-2</b><br>
#
# Молодец, что скорректировал функцию!)
# * Чтобы  взять первые 200 значений таргета (к-е соответствуют лучшим предсказаниям), можно  `result` отсортировать по убыванию и применить  `[:200]`
# </div>

# %% [markdown]
# Функция profit передает на выход суммарную прибыль с выбранных 200 самых больших по объему скважин.

# %% [markdown]
# Воспользуемся техникой `Bootstrap с 1000 выборок`, чтобы найти распределение прибыли.
#
# Далее найдем `среднюю прибыль`, `95%-й доверительный интервал` и `риск убытков`, который должен быть меньше **2.5%**

# %%
def characteristics(target,volume,BUDGET):
    state = np.random.RandomState(12345)
    lesion = []
    for i in range(1000):
        part_target = target.sample(n = 500, replace=True, random_state=state)
        volume = pd.Series(volume, name = 'predict')
        part_target = pd.Series(part_target, name = 'profits')
        volume_boot = volume.iloc[part_target.index] 
        part_target.reset_index(drop = True)
        volume_boot.reset_index(drop = True)
        boot = profit(part_target,volume_boot)
        lesion.append(boot-BUDGET)

    lesion = pd.Series(lesion)
    neg_count = len(list(filter(lambda x: (x < 0), lesion)))
    loss_probability = (neg_count/len(lesion))*100
    
    lower = lesion.quantile(0.025)
    upper = lesion.quantile(0.975)
    mean = lesion.mean()
    print("Риски убытка:", loss_probability)
    print(f"Средняя прибыль рублей: {round(mean)} рублей")
    print(f"95%-ый доверительный интервал: {round(lower)} : {round(upper)} рублей\n")
    return loss_probability, mean, lower, upper

# %% [markdown]
# <div class="alert alert-block alert-warning"><b>Комментарий ревьюера V-2</b>
#
# <b>Совет:</b><br>
# Обрати внимание на строки 👇
#
# ```python
# part_target.reset_index(drop = True)
# volume_boot.reset_index(drop = True)
# ```
# Чтобы сбросить индекс, надо присвоить, т.е.   `part_target = part_target.reset_index(drop = True)`  или использовать `inplace=True`
# </div>

# %% [markdown]
# Воспользуемся функцией для получения характеристик скважин `characteristics`

# %%
loss_probability1, lesion_mean1, lower1, upper1 = characteristics(target1_valid,volume1,BUDGET)
loss_probability2, lesion_mean2, lower2, upper2 = characteristics(target2_valid,volume2,BUDGET)
loss_probability3, lesion_mean3, lower3, upper3 = characteristics(target3_valid,volume3,BUDGET)
# Out:
# Риски убытка: 5.5
# Средняя прибыль рублей: 431538187 рублей
# 95%-ый доверительный интервал: -80924627 : 941037638 рублей
#
# Риски убытка: 2.0
# Средняя прибыль рублей: 477948839 рублей
# 95%-ый доверительный интервал: 51741836 : 897944131 рублей
#
# Риски убытка: 12.3
# Средняя прибыль рублей: 322147249 рублей
# 95%-ый доверительный интервал: -173464434 : 843529290 рублей

# %% [markdown]
# <div class="alert alert-block alert-success"><b>Комментарий ревьюера</b>
#
# <b>Успех:</b><br>
#     👍 Отлично, что при семплировании данных устанавливаешь `replace = True`, это необходимо чтобы наблюдение в выборку попало несколько раз, что позволяет добиться независимости при каждом выборе, иначе вероятность достать элемент из выборки будет с каждым разом увеличиваться. Чем больше размер подвыборки, тем выраженнее будет зависимость, поэтому без возврата не удастся получить разнообразные варианты, а подвыборку бОльшего размера вообще не получить.
#
# Почему именно так. Вспомним, что выборка - это некоторое представление о генеральной совокупности, ее часть. Значит, что где-то в регионе существуют и другие потенциальные точки добычи нефти, о которых мы можем не знать, но они являются частью этой генеральной совокупности. В этом случае повторяющиеся наблюдения можно считать разными точками добычи из всей генеральной совокупности с близкими характеристиками.
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-danger"><b>Комментарий ревьюера</b>
#
# <s> <b>Ошибка:</b><br>
# Максим, надо рассчитать среднюю прибыль, а у тебя выручка, т.е. `mean()` надо применить к `lesion`.  <br>
#     А еще надо рассчитать `quantile(0.025)`  и `quantile(0.975)`  для прибыли, т.е. для `lesion` </s>
# </div>

# %% [markdown]
# <div class="alert alert-info">
#     <h2> Комментарий студента <a class="tocSkip"></h2>
#
# <b> Замечения учтены, рассчитана правильно прибыль!</b>

# %% [markdown]
# <div class="alert alert-block alert-success"><b>Комментарий ревьюера </b><br>
#
#
# Что такое  `quantile()` очень хорошо объясняет пример - 0.5-й квантиль, это, по сути, медиана, т.е. функция `quantile(0.5)` должна вернуть такое значение, которое меньше ровно половины элементов массива.<br>
# `quantile(0.025)` находит такое значение прибыли,  меньше которого только 2,5% элементов. И если это значение прибыли положительное, значит и риск меньше 2,5%. <br>
# Выбирая наугад 1000 раз 500 случайных скважин и отбирая из них 200 лучших, убыток получаем менее, чем в 2,5% случаев.
#
#
# </div>

# %% [markdown]
# Для первого региона вероятность убытка равна 5.5 процентам. Также  95%-ый доверительный интервал  прибыли равен -80 млн.рублей : 941млн.рублей, а средняя выручка - 431 млн.рублей

# %% [markdown]
# Для второго региона вероятность убытка равна 2 процентам. Также  95%-ый доверительный интервал  прибыли равен 51 млн.рублей : 897 млн.рублей, а средняя выручка - 477 млн.рублей.
#
# 95%-ый доверительный интервал находится в положительном диапазоне - следоватьельно риск убытка меньше 2.5%

# %% [markdown]
# Для третьего региона вероятность убытка равна 12.3 процентам. Также  95%-ый доверительный интервал  прибыли равен -173 млн.рублей : 843 млн.рублей, а средняя выручка - 322 млн.рублей

# %% [markdown]
# На основании риска убытков и доверительного интервала - безубыточной разработкой можно заниматься только во втором регионе, благодаря лучшей модели машинного обучения.

# %% [markdown]
# ## Заключение

# %% [markdown]
# В данном проекте основной задачей являлось построение модели для определения региона, где добыча нефти принесёт наибольшую прибыль. Заказчиком являлся «ГлавРосГосНефть», который предоставил пробы нефти в трёх регионах.
#
# Нужно было подготовить данные и разбить на выборки: убучающую и валидационную. Нужно было обучить модель и сделать предсказания на валидационной выборке. Далее требовалось рассчитать достаточный объём сырья для безубыточной разработки новой скважины. Была написана функция для расчёта прибыли по выбранным скважинам и предсказаниям модели. В результате были посчитаны риски и прибыль для каждого региона.
#
# Можно сделать вывод, что только в одном регионе можно получить достаточную прибыль при минмальных рисках, в данном случае это `второй регион`.
#
# Полученные данные для сравнения приведены ниже:
#
# - Первый регион: Риски убытка - `5.5%`; Средняя прибыль - `431 млн.рублей`; Доверительный интервал прибыли -  **-80 млн.рублей : 941млн.рублей**
# - Второй регион: Риски убытка - `2.0%`; Средняя прибыль - `477 млн.рублей`; Доверительный интервал прибыли -  **51 млн.рублей : 897 млн.рублей**
# - Третий регион: Риски убытка - `12.3%`; Средняя прибыль - `322 млн.рублей`; Доверительный интервал прибыли -  **-173 млн.рублей : 843 млн.рублей**
#
# В результате анализа, самой эффективным регионом оказался второй, с вероятной чистой прибылью равной от 51 млн.рублей до 897 млн.рублей , и рисками равными 2.0%.
#
# Такой результат можно объяснить очень хорошим качеством модели предсказания для второго региона, благодаря этому возможно по данным о скажинах предположить самые прибыльные с большой вероятностью и минмальными убытками.

# %% [markdown]
# <div class="alert alert-block alert-success"><b>Комментарий ревьюера V-2</b>
#
# <b>Успех:</b><br>
#     👍 Регион выбран абсолютно верно. В этом регионе минимальный % риска, т.к. модель предсказывает хорошо (ошибка минимальная). А при выборе 200 лучших скважин мы опираемся на предсказания, поэтому ничего удивительного  -  регион победил!)
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-danger"><b>Комментарий ревьюера</b>
#
# <s> <b>Ошибка:</b><br>
# Максим, итоговый вывод после перерасчетов лучше скорректировать, чтобы он соответствовал полученным результатам)) </s>
# </div>

# %% [markdown]
# <div style="background: #cceeaa; padding: 5px; border: 1px solid green; border-radius: 5px;">
# <font color='green'>
#     <b><u>Общий вывод по проекту</u></b>
# <font color='green'><br>
#
#
# Максим, приложено много усилий, ты - молодец! Есть несколько важных моментов, которые я отметила и которые можно было бы улучшить, подсказки ты найдешь в моих комментариях.
#
# **Что мне особенно понравилось в твоей работе:**:
#
# * Есть знакомство с данными.
# * Рассчитан средний запас предсказанного сырья и размер ошибки для каждого региона.
# * Рассчитан достаточный объём сырья для безубыточной разработки новой скважины.
# * Написана функция для расчёта прибыли.
# * Использованы функции для повторяющихся действий.
# * Рассчитаны риски для каждого региона.
# * Есть выводы в каждом блоке.
# * Код логичный и понятный.
# * Проект полностью соответствует плану!<br>
#
#
# **На что стоит обратить внимание**:
#
# * Осталось совсем немного поправить, а именно: скорректировать `Bootstrap` (расчет средней прибыли и `quantile()`) и итоговый вывод. Подсказки ты найдешь в моих комментариях.
#
#
#
#
# **Доработка займет у тебя совсем немного времени) Желаю удачи и жду твой проект на повторное ревью!**😉

# %% [markdown]
# ## Чек-лист готовности проекта

# %% [markdown]
# Поставьте 'x' в выполненных пунктах. Далее нажмите Shift+Enter.

# %% [markdown]
# - [x]  Jupyter Notebook открыт
# - [x]  Весь код выполняется без ошибок
# - [x]  Ячейки с кодом расположены в порядке исполнения
# - [x]  Выполнен шаг 1: данные подготовлены
# - [x]  Выполнен шаг 2: модели обучены и проверены
#     - [x]  Данные корректно разбиты на обучающую и валидационную выборки
#     - [x]  Модели обучены, предсказания сделаны
#     - [x]  Предсказания и правильные ответы на валидационной выборке сохранены
#     - [x]  На экране напечатаны результаты
#     - [x]  Сделаны выводы
# - [x]  Выполнен шаг 3: проведена подготовка к расчёту прибыли
#     - [x]  Для всех ключевых значений созданы константы Python
#     - [x]  Посчитано минимальное среднее количество продукта в месторождениях региона, достаточное для разработки
#     - [x]  По предыдущему пункту сделаны выводы
#     - [x]  Написана функция расчёта прибыли
# - [x]  Выполнен шаг 4: посчитаны риски и прибыль
#     - [x]  Проведена процедура *Bootstrap*
#     - [x]  Все параметры бутстрепа соответствуют условию
#     - [x]  Найдены все нужные величины
#     - [x]  Предложен регион для разработки месторождения
#     - [x]  Выбор региона обоснован
